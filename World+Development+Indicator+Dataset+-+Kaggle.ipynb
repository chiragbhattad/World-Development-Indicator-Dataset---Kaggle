# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
cd "/Users/chiragbhattad/Downloads/world-development-indicators"
# Out:
# /Users/chiragbhattad/Downloads/world-development-indicators

# %%
ls
# Out:
# Country.csv*      Footnotes.csv*    Series.csv*       database.sqlite*
# CountryNotes.csv* Indicators.csv*   SeriesNotes.csv*  hashes.txt*

# %%
data = pd.read_csv("Indicators.csv")
data.shape
# Out:
# (5656458, 6)

# %%
data.head(10)
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
# 5  Arab World         ARB        Arms imports (SIPRI trend indicator values)
# 6  Arab World         ARB               Birth rate, crude (per 1,000 people)
# 7  Arab World         ARB                                 CO2 emissions (kt)
# 8  Arab World         ARB             CO2 emissions (metric tons per capita)
# 9  Arab World         ARB  CO2 emissions from gaseous fuel consumption (%...
#
#        IndicatorCode  Year         Value
# 0        SP.ADO.TFRT  1960  1.335609e+02
# ...

# %%
country = data['CountryName'].unique().tolist()
len(country)
# Out:
# 247

# %%
CountryCodes = data['CountryCode'].unique().tolist()
len(CountryCodes)
# Out:
# 247

# %%
indicator = data['IndicatorName'].unique().tolist()
print(len(indicator))
# Out:
# 1344

# %%
years = data['Year'].unique().tolist()
print(len(years))
# Out:
# 56

# %%
print(min(years)," to ", max(years))
# Out:
# 1960  to  2015

# %%
hist_indicator = 'EN.ATM.CO2E.PC'
hist_country = 'IND'

mask1 = data['IndicatorCode'].str.contains(hist_indicator)
mask2 = data['CountryCode'].str.contains(hist_country)
stage = data[mask1 & mask2]

# %%
stage.shape
stage.head(10)
# Out:
#        CountryName CountryCode                           IndicatorName  \
# 11577        India         IND  CO2 emissions (metric tons per capita)
# 36513        India         IND  CO2 emissions (metric tons per capita)
# 64049        India         IND  CO2 emissions (metric tons per capita)
# 92493        India         IND  CO2 emissions (metric tons per capita)
# 121290       India         IND  CO2 emissions (metric tons per capita)
# 151960       India         IND  CO2 emissions (metric tons per capita)
# 183696       India         IND  CO2 emissions (metric tons per capita)
# 215614       India         IND  CO2 emissions (metric tons per capita)
# 248229       India         IND  CO2 emissions (metric tons per capita)
# 281013       India         IND  CO2 emissions (metric tons per capita)
#
#          IndicatorCode  Year     Value
# 11577   EN.ATM.CO2E.PC  1960  0.268161
# 36513   EN.ATM.CO2E.PC  1961  0.284292
# 64049   EN.ATM.CO2E.PC  1962  0.306519
# ...

# %%
years = stage['Year'].values
co2 = stage['Value'].values
plt.bar(years,co2)
plt.show()

# %%
plt.plot(stage['Year'].values, stage['Value'].values)
plt.xlabel('Year')
plt.ylabel(stage['IndicatorName'].iloc[0])
plt.title('CO2 Emission in India over the years')
plt.axis([1959, 2011, 0, 2.0])
plt.show()

# %%
hist_data = stage['Value'].values
print(len(hist_data))
# Out:
# 52

# %%
plt.hist(hist_data, 10, normed=False, facecolor='green')

plt.xlabel(stage['IndicatorName'].iloc[0])
plt.ylabel('No. of Years')
plt.title('Histogram for CO2 Emission data of India')
plt.grid(True)
plt.show()

# %%
hist_indicator = 'EN.ATM.CO2E.PC'
hist_year = 2011

mask1 = data['IndicatorCode'].str.contains(hist_indicator)
mask2 = data['Year'].isin([hist_year])

co2_2011 = data[mask1 & mask2]
co2_2011.head(10)
# Out:
#                                        CountryName CountryCode  \
# 5026275                                 Arab World         ARB
# 5026788                     Caribbean small states         CSS
# 5027295             Central Europe and the Baltics         CEB
# 5027870    East Asia & Pacific (all income levels)         EAS
# 5028456      East Asia & Pacific (developing only)         EAP
# 5029230                                  Euro area         EMU
# 5029798  Europe & Central Asia (all income levels)         ECS
# 5030462    Europe & Central Asia (developing only)         ECA
# 5031318                             European Union         EUU
# 5031899   Fragile and conflict affected situations         FCS
#
#                                   IndicatorName   IndicatorCode  Year  \
# 5026275  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# 5026788  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# ...

# %%
print(len(co2_2011))
# Out:
# 232

# %%
fig, ax = plt.subplots()
ax.annotate("IND", xy=(1.6,5), xycoords='data', xytext=(10,30), textcoords='data',arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
           )
plt.hist(co2_2011['Value'], 10, normed=False, facecolor='Red')
plt.xlabel(stage['IndicatorName'].iloc[0])
plt.ylabel("No. of Countries")
plt.title('Histogram categorizing the countries based on their CO2 emission')
plt.grid(True)
plt.show()

# %%
hist_indicator = 'GDP per capita \(constant 2005'
hist_country = 'IND'
mask1 = data['IndicatorName'].str.contains(hist_indicator)
mask2 = data['CountryCode'].str.contains(hist_country)
gdp_stage = data[mask1 & mask2]
gdp_stage.shape
gdp_stage.head(10)
# Out:
#        CountryName CountryCode                       IndicatorName  \
# 11616        India         IND  GDP per capita (constant 2005 US$)
# 36555        India         IND  GDP per capita (constant 2005 US$)
# 64095        India         IND  GDP per capita (constant 2005 US$)
# 92540        India         IND  GDP per capita (constant 2005 US$)
# 121337       India         IND  GDP per capita (constant 2005 US$)
# 152009       India         IND  GDP per capita (constant 2005 US$)
# 183743       India         IND  GDP per capita (constant 2005 US$)
# 215661       India         IND  GDP per capita (constant 2005 US$)
# 248276       India         IND  GDP per capita (constant 2005 US$)
# 281060       India         IND  GDP per capita (constant 2005 US$)
#
#          IndicatorCode  Year       Value
# 11616   NY.GDP.PCAP.KD  1960  228.304470
# 36555   NY.GDP.PCAP.KD  1961  232.142053
# 64095   NY.GDP.PCAP.KD  1962  234.166685
# 92540   NY.GDP.PCAP.KD  1963  243.176418
# ...

# %%
stage.head(10)
# Out:
#        CountryName CountryCode                           IndicatorName  \
# 11577        India         IND  CO2 emissions (metric tons per capita)
# 36513        India         IND  CO2 emissions (metric tons per capita)
# 64049        India         IND  CO2 emissions (metric tons per capita)
# 92493        India         IND  CO2 emissions (metric tons per capita)
# 121290       India         IND  CO2 emissions (metric tons per capita)
# 151960       India         IND  CO2 emissions (metric tons per capita)
# 183696       India         IND  CO2 emissions (metric tons per capita)
# 215614       India         IND  CO2 emissions (metric tons per capita)
# 248229       India         IND  CO2 emissions (metric tons per capita)
# 281013       India         IND  CO2 emissions (metric tons per capita)
#
#          IndicatorCode  Year     Value
# 11577   EN.ATM.CO2E.PC  1960  0.268161
# 36513   EN.ATM.CO2E.PC  1961  0.284292
# 64049   EN.ATM.CO2E.PC  1962  0.306519
# ...

# %%
plt.plot(gdp_stage['Year'].values, gdp_stage['Value'].values)
plt.xlabel('Year')
plt.ylabel(gdp_stage['IndicatorName'].iloc[0])
plt.title('GDP per Capita of India')
plt.show()

# %%
print("GDP Min Year = ", gdp_stage['Year'].min(), "GDP Max Year = ", gdp_stage['Year'].max())
print("CO2 Min Year = ", stage['Year'].min(), "CO2 Max Year = ", stage['Year'].max())
# Out:
# GDP Min Year =  1960 GDP Max Year =  2014
# CO2 Min Year =  1960 CO2 Max Year =  2011

# %%
gdp_stage_trunc = gdp_stage[gdp_stage['Year']<2012]
print(len(gdp_stage_trunc))
print(len(stage))
# Out:
# 52
# 52

# %%
fig, axis = plt.subplots()
axis.yaxis.grid(True)
axis.set_title('CO2 Emission vs GDP per capita', fontsize=10)
axis.set_xlabel(gdp_stage_trunc['IndicatorName'].iloc[0], fontsize=10)
axis.set_ylabel(stage['IndicatorName'].iloc[0], fontsize=10)

X=gdp_stage_trunc['Value']
Y=stage['Value']

axis.scatter(X,Y)
plt.show()

# %%
np.corrcoef(gdp_stage_trunc['Value'], stage['Value'])
# Out:
# array([[ 1.        ,  0.96753758],
#        [ 0.96753758,  1.        ]])

# %%
indicator

# %%
hist_indicator1 = 'Merchandise exports \(current US'
hist_country = 'IND'
mask1 = data['IndicatorName'].str.contains(hist_indicator1)
mask2 = data['CountryCode'].str.contains(hist_country)
merc = data[mask1 & mask2]
merc.shape
# Out:
# (55, 6)

# %%
print(len(merc))
# Out:
# 55

# %%
merc_trunc = merc[merc['Year'] < 2012]
print(len(merc_trunc))
print(len(stage))
# Out:
# 52
# 52

# %%
fig, axis = plt.subplots()
axis.set_title('Correlation of CO2 Emission and Exports', fontsize = 10)
axis.set_xlabel(stage['IndicatorName'].iloc[0], fontsize=10)
axis.set_ylabel(merc_trunc['IndicatorName'].iloc[0])
X=stage['Value']
Y=merc_trunc['Value']
axis.scatter(X,Y)
plt.show()

# %%
np.corrcoef(merc_trunc['Value'], gdp_stage_trunc['Value'])
# Out:
# array([[ 1.        ,  0.93684907],
#        [ 0.93684907,  1.        ]])

# %%
yearFilter = [2010, 2011, 2012, 2013, 2014]
countryFilter = random.sample(country,2)

# %%
countryFilter
# Out:
# ['Denmark', 'Albania']

# %%
indicatorFilter = random.sample(indicator, 1)
indicatorFilter
# Out:
# ['Chemicals (% of value added in manufacturing)']

# %%
filterMesh = (data['CountryName'] == countryFilter[0]) & (data['IndicatorName'].isin(indicatorFilter)) & (data['Year'].isin(yearFilter))
country1_data = data.loc[filterMesh]
country1_data
# Out:
#         CountryName CountryCode  \
# 4903232     Denmark         DNK
#
#                                          IndicatorName      IndicatorCode  \
# 4903232  Chemicals (% of value added in manufacturing)  NV.MNF.CHEM.ZS.UN
#
#          Year      Value
# 4903232  2010  19.130898

# %%
filterMesh = (data['CountryName'] == countryFilter[1]) & (data['IndicatorName'].isin(indicatorFilter)) & (data['Year'].isin(yearFilter))
country2_data = data.loc[filterMesh]
country2_data
# Out:
#         CountryName CountryCode  \
# 4863052     Albania         ALB
# 5048412     Albania         ALB
#
#                                          IndicatorName      IndicatorCode  \
# 4863052  Chemicals (% of value added in manufacturing)  NV.MNF.CHEM.ZS.UN
# 5048412  Chemicals (% of value added in manufacturing)  NV.MNF.CHEM.ZS.UN
#
#          Year     Value
# 4863052  2010  4.586977
# 5048412  2011  9.104425

# %%
filteredData1 = []
filteredData2 = []

while(len(filteredData1) < len(yearFilter)-1):
    # pick new indicator
    indicatorFilter = random.sample(indicator, 1)
    countryFilter    = random.sample(country, 2)
    # how many rows are there that have this country name, this indicator, and this year.  Mesh gives bool vector
    filterMesh = (data['CountryName'] == countryFilter[0]) & (data['IndicatorName'].isin(indicatorFilter)) & (data['Year'].isin(yearFilter))
    # which rows have this condition to be true?
    filteredData1 = data.loc[filterMesh]
    filteredData1 = filteredData1[['CountryName','IndicatorName','Year','Value']]

    # need to print this only when our while condition is true
    if(len(filteredData1) < len(yearFilter)-1):
        print('Skipping ... %s since very few rows (%d) found' % (indicatorsFilter, len(filteredData1)))

# %%
indicatorFilter
# Out:
# ['Private credit bureau coverage (% of adults)']

# %%
len(filteredData1)
# Out:
# 5

# %%
while(len(filteredData2) < len(yearFilter)-1):
    filterMesh = (data['CountryName'] == countryFilter[1]) & (data['IndicatorName'].isin(indicatorFilter)) & (data['Year'].isin(yearFilter))
    # which rows have this condition to be true?
    filteredData2 = data.loc[filterMesh]
    filteredData2 = filteredData2[['CountryName','IndicatorName','Year','Value']]
    old = countryFilter[1]
    countryFilter[1] = random.sample(country,1)[0]

    # need to print this only when our while condition is true
    if(len(filteredData2) < len(yearFilter)-1):
        print('Skipping ... %s since very few rows (%d) found' % (indicatorFilter, len(filteredData2)))
# Out:
# Skipping ... ['Private credit bureau coverage (% of adults)'] since very few rows (0) found

# %%
if len(filteredData1) < len(filteredData2):
    small = len(filteredData1)
else:
    small = len(filteredData2)

# %%
filteredData1=filteredData1[0:small]
filteredData2=filteredData2[0:small]

# %%
filteredData1
# Out:
#         CountryName                                 IndicatorName  Year  Value
# 4918468     Germany  Private credit bureau coverage (% of adults)  2010   98.4
# 5100868     Germany  Private credit bureau coverage (% of adults)  2011  100.0
# 5276416     Germany  Private credit bureau coverage (% of adults)  2012  100.0
# 5443837     Germany  Private credit bureau coverage (% of adults)  2013  100.0
# 5578843     Germany  Private credit bureau coverage (% of adults)  2014  100.0

# %%
filteredData2
# Out:
#         CountryName                                 IndicatorName  Year  Value
# 4949270   Lithuania  Private credit bureau coverage (% of adults)  2010   67.8
# 5129818   Lithuania  Private credit bureau coverage (% of adults)  2011   75.6
# 5305466   Lithuania  Private credit bureau coverage (% of adults)  2012   81.2
# 5469532   Lithuania  Private credit bureau coverage (% of adults)  2013   89.4
# 5596803   Lithuania  Private credit bureau coverage (% of adults)  2014   97.7

# %%
fig, axis = plt.subplots()

axis.yaxis.grid(True)
axis.set_title(indicatorFilter[0], fontsize=10)
axis.set_xlabel(filteredData1['CountryName'].iloc[0], fontsize=10)
axis.set_ylabel(filteredData2['CountryName'].iloc[0], fontsize=10)

X=filteredData1['Value']
Y=filteredData2['Value']

axis.scatter(X, Y)
plt.show()

# %%
fig, axis = plt.subplots(figsize=(30,20))

axis.set_ylim(min(0, filteredData1['Value'].min()), 2*filteredData1['Value'].max())
axis.set_title('Indicator Name: ' + indicatorFilter[0], fontsize=10)
axis.plot(filteredData1['Year'], filteredData1['Value'], 'r--', label=filteredData1['CountryName'].unique())

legend = plt.legend(loc = 'upper centre', shadow=True, prop={'weight':'roman', 'size':'xx-large'})
frame=legend.get_frame()
plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/matplotlib/legend.py:326: UserWarning: Unrecognized location "upper centre". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   six.iterkeys(self.codes))))

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
countof_angles = 36
countof_radii = 8
array_rad = np.linspace(0.125, 1.0, countof_radii)
array_ang = np.linspace(0, 2*np.pi, countof_angles, endpoint=False)
array_ang = np.repeat(array_ang[...,np.newaxis], countof_radii, axis=1)
x=np.append(0, (array_rad*np.cos(array_ang)).flatten())
y=np.append(0, (array_rad*np.sin(array_ang)).flatten())
z=np.sin(-x*y)
fig = plt.figure(figsize=(20,10))
ax=fig.gca(projection='3d')
ax.plot_trisurf(x, y, z, cmap=cm.autumn)
plt.show()
fig.savefig("vid_3d.png")
